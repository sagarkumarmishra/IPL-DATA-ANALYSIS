# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarkumarmishra/IPL-DATA-ANALYSIS/blob/main/IPL_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/IPL_Matches_2008_2022.csv')

# %%
df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df.shape
# Out:
# (950, 20)

# %%
df.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
Dataframe = df.dropna()

# %%
Dataframe.shape
# Out:
# (19, 20)

# %%
print(df.head().to_string())
# Out:
#         ID       City        Date Season  MatchNumber                        Team1                 Team2                             Venue            TossWinner TossDecision SuperOver                  WinningTeam    WonBy  Margin method Player_of_Match                                                                                                                                                           Team1Players                                                                                                                                                         Team2Players        Umpire1        Umpire2
# ...

# %%
print(df.tail().to_string())
# Out:
#          ID        City        Date   Season MatchNumber                        Team1                        Team2                                       Venue                   TossWinner TossDecision SuperOver                  WinningTeam    WonBy  Margin method Player_of_Match                                                                                                                                              Team1Players                                                                                                                                              Team2Players    Umpire1         Umpire2
# ...

# %%
df['Team1'].value_counts().head(5)
# Out:
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Name: Team1, dtype: int64

# %%
df['Team2'].value_counts().head(5)
# Out:
# Mumbai Indians                 119
# Kolkata Knight Riders          118
# Rajasthan Royals               103
# Royal Challengers Bangalore    100
# Kings XI Punjab                 98
# Name: Team2, dtype: int64

# %%
df[['Team1','Team2','WinningTeam']].shape
# Out:
# (950, 3)

# %%
df.iloc[0]
# Out:
# ID                                                           1312200
# City                                                       Ahmedabad
# Date                                                      2022-05-29
# Season                                                          2022
# MatchNumber                                                    Final
# Team1                                               Rajasthan Royals
# Team2                                                 Gujarat Titans
# Venue                               Narendra Modi Stadium, Ahmedabad
# TossWinner                                          Rajasthan Royals
# TossDecision                                                     bat
# SuperOver                                                          N
# WinningTeam                                           Gujarat Titans
# WonBy                                                        Wickets
# Margin                                                           7.0
# ...

# %%
df.iloc[1:3]
# Out:
#         ID       City        Date Season  MatchNumber  \
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
#
#                          Team1                 Team2  \
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  \
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
df.iloc[1:11:2]
# Out:
#         ID       City        Date Season  MatchNumber  \
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 5  1304115     Mumbai  2022-05-21   2022           69
# 7  1304113     Mumbai  2022-05-19   2022           67
# 9  1304111     Mumbai  2022-05-17   2022           65
#
#                          Team1                        Team2  \
# 1  Royal Challengers Bangalore             Rajasthan Royals
# 3             Rajasthan Royals               Gujarat Titans
# 5               Delhi Capitals               Mumbai Indians
# 7               Gujarat Titans  Royal Challengers Bangalore
# 9          Sunrisers Hyderabad               Mumbai Indians
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
# 3             Eden Gardens, Kolkata    Gujarat Titans        field         N
# ...

# %%
df.iloc[:,[5,6,9,11]].head()
# Out:
#                          Team1                 Team2 TossDecision  \
# 0             Rajasthan Royals        Gujarat Titans          bat
# 1  Royal Challengers Bangalore      Rajasthan Royals        field
# 2  Royal Challengers Bangalore  Lucknow Super Giants        field
# 3             Rajasthan Royals        Gujarat Titans        field
# 4          Sunrisers Hyderabad          Punjab Kings          bat
#
#                    WinningTeam
# 0               Gujarat Titans
# 1             Rajasthan Royals
# 2  Royal Challengers Bangalore
# 3               Gujarat Titans
# 4                 Punjab Kings

# %%
df.iloc[:,[5,6,9,11]]
# Out:
#                            Team1                        Team2 TossDecision  \
# 0               Rajasthan Royals               Gujarat Titans          bat
# 1    Royal Challengers Bangalore             Rajasthan Royals        field
# 2    Royal Challengers Bangalore         Lucknow Super Giants        field
# 3               Rajasthan Royals               Gujarat Titans        field
# 4            Sunrisers Hyderabad                 Punjab Kings          bat
# ..                           ...                          ...          ...
# 945        Kolkata Knight Riders              Deccan Chargers          bat
# 946               Mumbai Indians  Royal Challengers Bangalore          bat
# 947             Delhi Daredevils             Rajasthan Royals          bat
# 948              Kings XI Punjab          Chennai Super Kings          bat
# 949  Royal Challengers Bangalore        Kolkata Knight Riders        field
#
#                      WinningTeam
# 0                 Gujarat Titans
# ...

# %%
type(df['City']=='Ahmedabad')
# Out:
# pandas.core.series.Series

# %%
df['City']=='Ahmedabad'
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: City, Length: 950, dtype: bool

# %%
mask = df['City']=='Ahmedabad'
df[mask].shape[0]
# Out:
# 19

# %%
def get_city_match(city):
    return df[df['City']==city].shape[0]

get_city_match('Ahmedabad')

df['City'].value_counts()
# Out:
# Mumbai            159
# Kolkata            79
# Delhi              78
# Chennai            67
# Bangalore          65
# Hyderabad          64
# Chandigarh         56
# Pune               51
# Jaipur             47
# Abu Dhabi          37
# Ahmedabad          19
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Dubai              13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Dharamsala          9
# Navi Mumbai         9
# Indore              9
# Johannesburg        8
# Ranchi              7
# Cuttack             7
# Port Elizabeth      7
# Cape Town           7
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: City, dtype: int64

# %%
get_city_match('Ranchi')
# Out:
# 7

# %%
mask = df['City']=='Ahmedabad'
mask2 = df['City']>'2022-05-27'

df[mask & mask2].shape[0]
# Out:
# 19

# %%
df['WinningTeam'].value_counts()
# Out:
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Rajasthan Royals                96
# Kings XI Punjab                 88
# Sunrisers Hyderabad             75
# Delhi Daredevils                67
# Delhi Capitals                  36
# Deccan Chargers                 29
# Gujarat Lions                   13
# Punjab Kings                    13
# Pune Warriors                   12
# Gujarat Titans                  12
# Rising Pune Supergiant          10
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: WinningTeam, dtype: int64

# %%
df['WinningTeam'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df['WinningTeam'].value_counts().head().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df['WinningTeam'].value_counts().head().plot(kind = 'barh')
# Out:
# <Axes: >

# %%
df['TossDecision'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='TossDecision'>

# %%
df['WonBy'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='WonBy'>

# %%
df['Margin'].value_counts().plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Team1'].value_counts()
# Out:
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: Team1, dtype: int64

# %%
type(df['Team1'].value_counts())
# Out:
# pandas.core.series.Series

# %%
myseries = df['Team1'].value_counts()

# %%
myseries.values
# Out:
# array([126, 112, 111, 105,  92,  89,  85,  69,  39,  29,  23,  18,  16,
#          8,   7,   7,   7,   7])

# %%
total_matches =df['Team1'].value_counts() + df['Team2'].value_counts()

# %%
total_matches.head().sort_values(ascending= False)
# Out:
# Chennai Super Kings    208
# Delhi Daredevils       161
# Deccan Chargers         75
# Delhi Capitals          63
# Gujarat Lions           30
# dtype: int64

# %%
total_matches.sort_values(ascending= False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# dtype: int64

# %%
total_matches.sort_index()
# Out:
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                  63
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   46
# Punjab Kings                    28
# Rajasthan Royals               192
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    226
# Sunrisers Hyderabad            152
# dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df['City'].sort_values(ascending = False)
# Out:
# 472    Visakhapatnam
# 195    Visakhapatnam
# 696    Visakhapatnam
# 387    Visakhapatnam
# 693    Visakhapatnam
#            ...
# 543              NaN
# 545              NaN
# 546              NaN
# 547              NaN
# 550              NaN
# Name: City, Length: 950, dtype: object

# %%
df.sort_values('City',ascending = False)
# Out:
#           ID           City        Date Season MatchNumber  \
# 472   829743  Visakhapatnam  2015-04-22   2015          19
# 195  1181767  Visakhapatnam  2019-05-10   2019   Qualifier
# 696   548311  Visakhapatnam  2012-04-07   2012           6
# 387   980993  Visakhapatnam  2016-05-15   2016          47
# 693   548314  Visakhapatnam  2012-04-09   2012           9
# ..       ...            ...         ...    ...         ...
# 543   729295            NaN  2014-04-22   2014           9
# 545   729291            NaN  2014-04-20   2014           7
# 546   729289            NaN  2014-04-19   2014           6
# 547   729287            NaN  2014-04-19   2014           5
# 550   729281            NaN  2014-04-17   2014           2
#
#                            Team1                        Team2  \
# 472          Sunrisers Hyderabad        Kolkata Knight Riders
# 195               Delhi Capitals          Chennai Super Kings
# 696              Deccan Chargers          Chennai Super Kings
# ...

# %%
df.sort_values('City',ascending = True)
# Out:
#           ID       City        Date   Season  MatchNumber  \
# 135  1237180  Abu Dhabi  2020-11-08  2020/21  Qualifier 2
# 95   1254098  Abu Dhabi  2021-09-26     2021           38
# 533   729315  Abu Dhabi  2014-04-29     2014           19
# 181  1216503  Abu Dhabi  2020-10-01  2020/21           13
# 92   1254099  Abu Dhabi  2021-09-28     2021           42
# ..       ...        ...         ...      ...          ...
# 543   729295        NaN  2014-04-22     2014            9
# 545   729291        NaN  2014-04-20     2014            7
# 546   729289        NaN  2014-04-19     2014            6
# 547   729287        NaN  2014-04-19     2014            5
# 550   729281        NaN  2014-04-17     2014            2
#
#                            Team1                        Team2  \
# 135               Delhi Capitals          Sunrisers Hyderabad
# 95         Kolkata Knight Riders          Chennai Super Kings
# 533        Kolkata Knight Riders             Rajasthan Royals
# ...

# %%
df.sort_values(['City','Date'],ascending =[True,False])
# Out:
#           ID       City        Date Season MatchNumber  \
# 79   1254088  Abu Dhabi  2021-10-08   2021          55
# 82   1254095  Abu Dhabi  2021-10-06   2021          52
# 88   1254089  Abu Dhabi  2021-10-02   2021          47
# 92   1254099  Abu Dhabi  2021-09-28   2021          42
# 95   1254098  Abu Dhabi  2021-09-26   2021          38
# ..       ...        ...         ...    ...         ...
# 543   729295        NaN  2014-04-22   2014           9
# 545   729291        NaN  2014-04-20   2014           7
# 546   729289        NaN  2014-04-19   2014           6
# 547   729287        NaN  2014-04-19   2014           5
# 550   729281        NaN  2014-04-17   2014           2
#
#                            Team1                        Team2  \
# 79                Mumbai Indians          Sunrisers Hyderabad
# 82           Sunrisers Hyderabad  Royal Challengers Bangalore
# 88           Chennai Super Kings             Rajasthan Royals
# ...

# %%
df['City'].drop_duplicates().shape
# Out:
# (34,)

# %%
df.drop_duplicates('City')
# Out:
#           ID            City        Date   Season  MatchNumber  \
# 0    1312200       Ahmedabad  2022-05-29     2022        Final
# 2    1312198         Kolkata  2022-05-25     2022   Eliminator
# 4    1304116          Mumbai  2022-05-22     2022           70
# 8    1304112     Navi Mumbai  2022-05-18     2022           66
# 13   1304107            Pune  2022-05-14     2022           61
# 74   1254117           Dubai  2021-10-15     2021        Final
# 75   1254116         Sharjah  2021-10-13     2021  Qualifier 2
# 79   1254088       Abu Dhabi  2021-10-08     2021           55
# 106  1254085           Delhi  2021-05-02     2021           28
# 114  1254077         Chennai  2021-04-25     2021           20
# 134  1237181             NaN  2020-11-10  2020/21        Final
# 194  1181768       Hyderabad  2019-05-12     2019        Final
# 195  1181767   Visakhapatnam  2019-05-10     2019    Qualifier
# 198  1178430      Chandigarh  2019-05-05     2019           55
# ...

# %%
df.drop_duplicates('City').shape
# Out:
# (34, 20)

# %%
df.drop_duplicates(subset=['City','Date'],keep = 'first')
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df.drop_duplicates(subset=['City','Date'],keep = 'first').shape
# Out:
# (927, 20)

# %%
df.drop_duplicates(subset = 'Season',keep = 'last')[['Season','WinningTeam']]
# Out:
#       Season                  WinningTeam
# 73      2022        Kolkata Knight Riders
# 133     2021  Royal Challengers Bangalore
# 193  2020/21          Chennai Super Kings
# 253     2019          Chennai Super Kings
# 313     2018          Chennai Super Kings
# 372     2017          Sunrisers Hyderabad
# 432     2016      Rising Pune Supergiants
# 491     2015        Kolkata Knight Riders
# 551     2014        Kolkata Knight Riders
# 627     2013        Kolkata Knight Riders
# 701     2012               Mumbai Indians
# 774     2011          Chennai Super Kings
# 834  2009/10        Kolkata Knight Riders
# 891     2009               Mumbai Indians
# 949  2007/08        Kolkata Knight Riders

# %%
df.drop_duplicates(subset = 'Season',keep = 'first')[['Season','WinningTeam']].sort_values('Season')
# Out:
#       Season            WinningTeam
# 892  2007/08       Rajasthan Royals
# 835     2009        Deccan Chargers
# 775  2009/10    Chennai Super Kings
# 702     2011    Chennai Super Kings
# 628     2012  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 433     2015         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 314     2017         Mumbai Indians
# 254     2018    Chennai Super Kings
# 194     2019         Mumbai Indians
# 134  2020/21         Mumbai Indians
# 74      2021    Chennai Super Kings
# 0       2022         Gujarat Titans
